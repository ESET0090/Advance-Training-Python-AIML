# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\user\\Downloads\\50_Startups.csv')

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df.shape
# Out:
# (50, 5)

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df = df.drop(['State','Administration'], axis = 1)

# %%
df
# Out:
#     R&D Spend  Marketing Spend     Profit
# 0   165349.20        471784.10  192261.83
# 1   162597.70        443898.53  191792.06
# 2   153441.51        407934.54  191050.39
# 3   144372.41        383199.62  182901.99
# 4   142107.34        366168.42  166187.94
# 5   131876.90        362861.36  156991.12
# 6   134615.46        127716.82  156122.51
# 7   130298.13        323876.68  155752.60
# 8   120542.52        311613.29  152211.77
# 9   123334.88        304981.62  149759.96
# 10  101913.08        229160.95  146121.95
# 11  100671.96        249744.55  144259.40
# 12   93863.75        249839.44  141585.52
# 13   91992.39        252664.93  134307.35
# 14  119943.24        256512.92  132602.65
# 15  114523.61        261776.23  129917.04
# 16   78013.11        264346.06  126992.93
# 17   94657.16        282574.31  125370.37
# 18   91749.16        294919.57  124266.90
# 19   86419.70             0.00  122776.86
# 20   76253.86        298664.47  118474.03
# ...

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Marketing Spend    0
# Profit             0
# dtype: int64

# %%
correlation_matrix = df.corr()

# %%
correlation_matrix
# Out:
#                  R&D Spend  Marketing Spend    Profit
# R&D Spend         1.000000         0.724248  0.972900
# Marketing Spend   0.724248         1.000000  0.747766
# Profit            0.972900         0.747766  1.000000

# %%
sns.pairplot(df)

# %% [markdown]
# ## Both the features Marketing Spend and R&D Spend are related with the final o/p column of Profit

# %%
correlation_matrix = df.corr()

# %%
correlation_matrix
# Out:
#                  R&D Spend  Marketing Spend    Profit
# R&D Spend         1.000000         0.724248  0.972900
# Marketing Spend   0.724248         1.000000  0.747766
# Profit            0.972900         0.747766  1.000000

# %%
sns.heatmap(correlation_matrix, annot = True)
# Out:
# <Axes: >

# %%
y = df['Profit']
X = df.drop(columns=['Profit'])

# %%
print(y)
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
print(X)
# Out:
#     R&D Spend  Marketing Spend
# 0   165349.20        471784.10
# 1   162597.70        443898.53
# 2   153441.51        407934.54
# 3   144372.41        383199.62
# 4   142107.34        366168.42
# 5   131876.90        362861.36
# 6   134615.46        127716.82
# 7   130298.13        323876.68
# 8   120542.52        311613.29
# 9   123334.88        304981.62
# 10  101913.08        229160.95
# 11  100671.96        249744.55
# 12   93863.75        249839.44
# 13   91992.39        252664.93
# 14  119943.24        256512.92
# 15  114523.61        261776.23
# 16   78013.11        264346.06
# 17   94657.16        282574.31
# 18   91749.16        294919.57
# 19   86419.70             0.00
# 20   76253.86        298664.47
# 21   78389.47        299737.29
# 22   73994.56        303319.26
# 23   67532.53        304768.73
# 24   77044.01        140574.81
# 25   64664.71        137962.62
# 26   75328.87        134050.07
# 27   72107.60        353183.81
# 28   66051.52        118148.20
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20, random_state = 42)

# %%
print(X_train)
print(X_test)
print(y_train)
print(y_test)
# Out:
#     R&D Spend  Marketing Spend
# 12   93863.75        249839.44
# 4   142107.34        366168.42
# 37   44069.95        197029.42
# 8   120542.52        311613.29
# 3   144372.41        383199.62
# 6   134615.46        127716.82
# 41   27892.92        164470.71
# 46    1315.46        297114.46
# 47       0.00             0.00
# 15  114523.61        261776.23
# 9   123334.88        304981.62
# 16   78013.11        264346.06
# 24   77044.01        140574.81
# 34   46426.07        210797.67
# 31   61136.38         88218.23
# 0   165349.20        471784.10
# 44   22177.74         28334.72
# 27   72107.60        353183.81
# 33   55493.95        214634.81
# 5   131876.90        362861.36
# 29   65605.48        107138.38
# 11  100671.96        249744.55
# 36   28663.76        201126.82
# 1   162597.70        443898.53
# 21   78389.47        299737.29
# 2   153441.51        407934.54
# 43   15505.73         35534.17
# 35   46014.02        205517.64
# 23   67532.53        304768.73
# ...

# %%
plt.figure(figsize= (12,6))
plt.subplot(1,2,1)
plt.scatter(df['R&D Spend'], df['Profit'], c = 'red')
plt.xlabel('R&D Spend')
plt.ylabel('Profit')
plt.title('R&D Spend Vs Profit')
plt.subplot(1,2,2)
plt.scatter(df['Marketing Spend'], df['Profit'], c = 'blue')
plt.xlabel('Marketing Spend')
plt.ylabel('Profit')
plt.title('Marketing Spend Vs Profit')
plt.show()

# %%
sns.regplot(x = df['R&D Spend'], y = df['Profit'])
# Out:
# <Axes: xlabel='R&D Spend', ylabel='Profit'>

# %%
sns.regplot(x = df['Marketing Spend'], y = df['Profit'])
# Out:
# <Axes: xlabel='Marketing Spend', ylabel='Profit'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()
X_train = scalar.fit_transform(X_train)
X_test = scalar.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.34202149,  0.12425038],
#        [ 1.36207849,  1.14990688],
#        [-0.71081297, -0.34136825],
#        [ 0.90611438,  0.66890185],
#        [ 1.40997088,  1.30006861],
#        [ 1.20367103, -0.95248784],
#        [-1.05285826, -0.62843389],
#        [-1.61480906,  0.54106768],
#        [-1.642623  , -2.07854935],
#        [ 0.77885123,  0.2294954 ],
#        [ 0.96515572,  0.61043134],
#        [ 0.00687736,  0.25215324],
#        [-0.01361318, -0.83912073],
#        [-0.66099544, -0.2199755 ],
#        [-0.34996231, -1.30074144],
#        [ 1.85350175,  2.08110569],
#        [-1.17369938, -1.82872605],
#        [-0.11798808,  1.03542337],
#        [-0.46926521, -0.18614397],
#        [ 1.14576723,  1.12074899],
#        [-0.25546817, -1.1339251 ],
#        [ 0.48597351,  0.12341374],
#        [-1.03655971, -0.30524204],
#        [ 1.79532434,  1.83524249],
#        [ 0.01483507,  0.56419281],
#        [ 1.6017269 ,  1.51815297],
#        [-1.3147716 , -1.7652495 ],
# ...

# %%
X_test
# Out:
# array([[ 0.30245367,  0.14916233],
#        [-0.82734624, -0.53560477],
#        [-0.33181874, -1.27505783],
#        [-1.62147425, -2.06176266],
#        [ 0.35879726,  0.41286919],
#        [-1.63116196, -2.07854935],
#        [-0.04987791, -0.89664846],
#        [-0.2753597 , -0.86215204],
#        [-0.30191325, -1.67222209],
#        [ 0.18462534, -2.07854935]])

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import cross_val_score
validation_score = cross_val_score(regression,X_train,y_train,scoring='neg_mean_squared_error', cv = 3)

# %%
np.mean(validation_score)
# Out:
# np.float64(-93158023.25525002)

# %%
## Prediction

# %%
y_pred = regression.predict(X_test)

# %%
y_pred
# Out:
# array([127521.38604123,  82615.07411457,  97683.2462344 ,  46400.65677644,
#        130782.53611917,  45967.0205249 , 109813.19061887, 101612.68921418,
#         97023.64013854, 113241.36575804])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 67343832.58979613
# 6469.1817214685925
# 8206.328813165856

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(y_test, y_pred)

# %%
score
# Out:
# 0.9168381183550247

# %%
plt.scatter(y_pred, y_test)

# %%
residual = y_test - y_pred
print(residual)
# Out:
# 13     6785.963959
# 39    -1609.314115
# 30     2254.343766
# 45    18525.423224
# 17    -5412.166119
# 48   -10293.610525
# 26    -4079.650619
# 25     5791.650786
# 32      404.199861
# 19     9535.494242
# Name: Profit, dtype: float64

# %%
## Plot the Residual

sns.displot(x=residual, kind="kde")

# %%
plt.scatter(y_pred, residual, c = 'red')
plt.xlabel('y_pred')
plt.ylabel('residual')
# Out:
# Text(0, 0.5, 'residual')

# %%
print("Shape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of prediction:", regression.predict(X_train).shape)
# Out:
# Shape of X_train: (40, 2)
# Shape of y_train: (40,)
# Shape of prediction: (40,)

# %%
import matplotlib.pyplot as plt

y_pred = regression.predict(X_train)

plt.figure(figsize=(8, 6))
plt.scatter(y_train, y_pred, alpha=0.7)
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'r--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs. Actual Values')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Polynomial Regression

# %%
degree = 2
poly = PolynomialFeatures(degree=degree)

# %%
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
scaler = StandardScaler()
X_train_poly_scaled = scaler.fit_transform(X_train_poly)
X_test_poly_scaled = scaler.transform(X_test_poly)

# %%
poly_regression = LinearRegression()
poly_regression.fit(X_train_poly_scaled, y_train)
# Out:
# LinearRegression()

# %%
validation_score = cross_val_score(poly_regression, X_train_poly_scaled, y_train, 
                                 scoring='neg_mean_squared_error', cv=3)

# %%
y_pred_poly = poly_regression.predict(X_test_poly_scaled)

# %%
mse_poly = mean_squared_error(y_test, y_pred_poly)
mae_poly = mean_absolute_error(y_test, y_pred_poly)
rmse_poly = np.sqrt(mse_poly)
r2_poly = r2_score(y_test, y_pred_poly)

# %%
print(mse_poly)
print(mae_poly)
print(rmse_poly)
# Out:
# 102196166.9588066
# 7883.508851666852
# 10109.211985056332

# %%
print(r2_poly)
# Out:
# 0.8737994970828828

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred_poly, alpha=0.7, color='green')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Actual Profit')
plt.ylabel('Predicted Profit')
plt.title(f'Polynomial Regression (Degree {degree}): Actual vs Predicted')
plt.show()
